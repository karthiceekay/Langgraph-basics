# %%
from typing import TypedDict, Annotated
from langgraph.graph.message import AnyMessage

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
class state(TypedDict):
    messages : Annotated[list, AnyMessage]

# %%
from langchain_groq import ChatGroq
from langchain.chat_models import init_chat_model

llm=ChatGroq(model="llama3-8b-8192")

# %%
from langchain_community.tools import WikipediaQueryRun, ArxivQueryRun
from langchain_community.utilities import WikipediaAPIWrapper, ArxivAPIWrapper

wikipedia_tool = WikipediaQueryRun(WikipediaAPIWrapper())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File e:\AI_LEARNING\LANGGRAPH_BASICS\AI_PROJECTS\AGENTICAIBASICS\.venv\Lib\site-packages\langchain_community\utilities\wikipedia.py:35, in WikipediaAPIWrapper.validate_environment(cls, values)
#      34 try:
# ---> 35     import wikipedia
#      37     lang = values.get("lang", "en")
#
# ModuleNotFoundError: No module named 'wikipedia'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 4
#       1 from langchain_community.tools import WikipediaQueryRun, ArxivQueryRun
#       2 from langchain_community.utilities import WikipediaAPIWrapper, ArxivAPIWrapper
# ----> 4 wikipedia_tool = WikipediaQueryRun(WikipediaAPIWrapper())
#
#     [... skipping hidden 1 frame]
#
# File e:\AI_LEARNING\LANGGRAPH_BASICS\AI_PROJECTS\AGENTICAIBASICS\.venv\Lib\site-packages\langchain_community\utilities\wikipedia.py:41, in WikipediaAPIWrapper.validate_environment(cls, values)
#      39     values["wiki_client"] = wikipedia
#      40 except ImportError:
# ---> 41     raise ImportError(
#      42         "Could not import wikipedia python package. "
#      43         "Please install it with `pip install wikipedia`."
#      44     )
#      45 return values
#
# ImportError: Could not import wikipedia python package. Please install it with `pip install wikipedia`.
